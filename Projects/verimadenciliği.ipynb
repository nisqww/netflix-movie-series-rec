# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.api.types import CategoricalDtype

# %%
data = pd.read_csv("netflix_titles.csv",encoding='latin-1')
df = data.copy()

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  ... Unnamed: 16  \
# 0  September 25, 2021          2020  PG-13     90 min  ...         NaN
# ...

# %%
data["Unnamed: 12"]
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 8804   NaN
# 8805   NaN
# 8806   NaN
# 8807   NaN
# 8808   NaN
# Name: Unnamed: 12, Length: 8809, dtype: float64

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# Unnamed: 12     8809
# Unnamed: 13     8809
# Unnamed: 14     8809
# Unnamed: 15     8809
# Unnamed: 16     8809
# Unnamed: 17     8809
# Unnamed: 18     8809
# Unnamed: 19     8809
# Unnamed: 20     8809
# Unnamed: 21     8809
# Unnamed: 22     8809
# Unnamed: 23     8809
# Unnamed: 24     8809
# Unnamed: 25     8809
# dtype: int64

# %%
df['director'] = df['director'].fillna(0)
df['cast'] = df['cast'].fillna(0)
df['country'] = df['country'].fillna(0)
df['date_added'] = df["date_added"].fillna(0)
Unnamed = ['Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
       'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
       'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
       'Unnamed: 24', 'Unnamed: 25']
df = df.drop(columns=Unnamed,axis=1)

# %%
kat_df = df.select_dtypes(include=['object'])
kat_df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water                0
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans                0
# 4      s5  TV Show           Kota Factory                0
#
#                                                 cast        country  \
# 0                                                  0  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...              0
# 3                                                  0              0
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added rating   duration  \
# 0  September 25, 2021  PG-13     90 min
# 1  September 24, 2021  TV-MA  2 Seasons
# 2  September 24, 2021  TV-MA   1 Season
# ...

# %%
df.type.head()
# Out:
# 0      Movie
# 1    TV Show
# 2    TV Show
# 3    TV Show
# 4    TV Show
# Name: type, dtype: object

# %%
df.type = df.type.astype(CategoricalDtype(ordered=True))
df.type
# Out:
# 0         Movie
# 1       TV Show
# 2       TV Show
# 3       TV Show
# 4       TV Show
#          ...
# 8804      Movie
# 8805      Movie
# 8806      Movie
# 8807    TV Show
# 8808      Movie
# Name: type, Length: 8809, dtype: category
# Categories (2, object): ['Movie' < 'TV Show']

# %%
df.type.value_counts()
# Out:
# type
# Movie      6132
# TV Show    2677
# Name: count, dtype: int64

# %%
df.rating.value_counts()
# Out:
# rating
# TV-MA       3208
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# A              1
# Name: count, dtype: int64

# %%
listed_in = df.listed_in.astype(CategoricalDtype(ordered=True))
listed_in
df.listed_in.value_counts()
# Out:
# listed_in
# Dramas, International Movies                          362
# Documentaries                                         359
# Stand-Up Comedy                                       334
# Comedies, Dramas, International Movies                274
# Dramas, Independent Movies, International Movies      252
#                                                      ...
# TV Comedies, TV Dramas, TV Horror                       1
# Children & Family Movies, Comedies, LGBTQ Movies        1
# Kids' TV, Spanish-Language TV Shows, Teen TV Shows      1
# Horror Movies, LGBTQ Movies, Music & Musicals           1
# Drama, Romance, Thriller                                1
# Name: count, Length: 516, dtype: int64

# %%
action_movies = df[df['listed_in'].str.contains('Action', case=False, na=False)]
action_movies
# Out:
#      show_id     type                          title           director  \
# 2         s3  TV Show                      Ganglands    Julien Leclercq
# 11       s12  TV Show               Bangkok Breaking  Kongkiat Komesiri
# 19       s20  TV Show                         Jaguar                  0
# 21       s22  TV Show         Resurrection: Ertugrul                  0
# 36       s37    Movie                 The Stronghold    C̩dric Jimenez
# ...      ...      ...                            ...                ...
# 8767   s8768    Movie        XXX: State of the Union       Lee Tamahori
# 8772   s8773    Movie          Yamla Pagla Deewana 2     Sangeeth Sivan
# 8790   s8791    Movie  You Don't Mess with the Zohan       Dennis Dugan
# 8792   s8793    Movie                    Young Tiger             Mu Chu
# 8807   s8808  TV Show             Parasyte: The Grey       Yeon Sang-ho
#
#                                                    cast        country  \
# ...

# %%
country_list = pd.read_excel("Country.xlsx")
country_list
# Out:
#            country
# 0    United States
# 1           Canada
# 2   United Kingdom
# 3          Germany
# 4           France
# 5            Spain
# 6            Italy
# 7            India
# 8            Japan
# 9      South Korea
# 10          Mexico
# 11          Brazil
# 12       Australia
# 13     New Zealand
# 14       Argentina
# 15         Belgium
# 16         Denmark
# 17         Finland
# 18          Norway
# 19          Sweden
# 20          Turkey
# 21    South Africa
# 22        Colombia
# 23     Netherlands
# 24          Poland
# 25     Switzerland
# 26         Austria
# 27         Ireland
# 28        Portugal
# 29           Chile
# 30          Israel
# 31        Malaysia
# 32       Singapore
# 33        Thailand
# 34       Indonesia
# 35     Philippines
# 36          Taiwan
# 37       Hong Kong
# 38            Peru
# 39  Czech Republic
# 40         Hungary
# 41         Romania
# 42        Slovakia
# 43          Greece
# 44        Bulgaria
# 45         Croatia
# ...

# %%
merged_df = pd.merge(df, country_list, on='country')
merged_df['country'].value_counts()
# Out:
# country
# United States     2819
# India              972
# United Kingdom     419
# Japan              245
# South Korea        200
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Turkey             105
# Nigeria             95
# Australia           87
# Taiwan              81
# Indonesia           79
# Brazil              77
# Philippines         75
# Germany             67
# Thailand            61
# Argentina           56
# Hong Kong           53
# Italy               45
# Colombia            35
# South Africa        30
# Poland              24
# Singapore           23
# Malaysia            22
# Netherlands         19
# Chile               14
# Israel              13
# Sweden              13
# Denmark             13
# New Zealand         12
# Norway              11
# Ireland             10
# Belgium              9
# Romania              6
# Austria              5
# Iceland              5
# ...

# %%
rating_list = list(set(df['rating'].values))
rating_list
#type(df['rating'].values)
# Out:
# ['84 min',
#  '74 min',
#  'R',
#  'A',
#  nan,
#  'PG-13',
#  '66 min',
#  'TV-G',
#  'NC-17',
#  'TV-Y',
#  'PG',
#  'TV-Y7',
#  'NR',
#  'TV-Y7-FV',
#  'UR',
#  'G',
#  'TV-14',
#  'TV-PG',
#  'TV-MA']

# %%
rating_list = pd.read_excel("Rating.xlsx")
rating_list
# Out:
#       Rating
# 0     84 min
# 1     74 min
# 2          R
# 3          A
# 4        NaN
# 5    PG - 13
# 6     66 min
# 7      TV- G
# 8      NC-17
# 9      TV-Y7
# 10        NR
# 11  TV-Y7-FV
# 12        UR
# 13         G
# 14     TV-14
# 15     TV-PG
# 16     TV-MA
